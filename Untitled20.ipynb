# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
import edhec_risk_kit as erk
from scipy.optimize import minimize
from numpy.linalg import inv

# %load_ext autoreload
# %autoreload 2

# %%
erk.bond_price(5,100,0.05,12,.03)
# Out:
# 0    109.275393
# dtype: float64

# %%
rates, zc_prices = erk.cir(10,500,b=0.03,r_0=0.03)

# %%
erk.bond_price(5,100,0.05,12,rates.iloc[0][[1,2,3]])
# Out:
# 1    109.275393
# 2    109.275393
# 3    109.275393
# dtype: float64

# %%
erk.bond_price(5,100,0.05,12,rates.iloc[2][[1,2,3]])
# Out:
# 1    112.625013
# 2    111.188631
# 3    106.419796
# dtype: float64

# %%
erk.bond_price(10,100,.05,12,rates[[1,2,3,4,5]]).plot(legend=False, figsize=(12,6))

# %%
prices = erk.bond_price(10,100,.05,12,rates[[1,2,3,4,5]])
prices.tail()
# Out:
#            1        2        3        4        5
# 116  100.637   100.54  100.898  100.409  100.734
# 117  100.418  100.462   100.62   100.35  100.532
# 118  100.227  100.318  100.379  100.217  100.331
# 119  100.098  100.197  100.193   100.13  100.194
# 120  100.417  100.417  100.417  100.417  100.417

# %%
br=prices.pct_change().dropna()
erk.annualize_rets(br,12)
# Out:
# 1   -0.015387
# 2   -0.015387
# 3   -0.015387
# 4   -0.015387
# 5   -0.015387
# dtype: float64

# %%
## we forgot to ass the coupon retrns : not just the prices  but also coupons

# %%
p = erk.bond_price(10,100,0.05,12,rates[[1,2,3,4,]])
btr=erk.bond_total_return(p,100,0.05,12)
erk.annualize_rets(btr,12)
# Out:
# 1    0.030766
# 2    0.029748
# 3    0.030906
# 4    0.032244
# dtype: float64

# %%
price_10=erk.bond_price(10,100,.05,12,rates)
price_10[[1,2,3]].tail()
# Out:
#            1        2        3
# 116  100.637   100.54  100.898
# 117  100.418  100.462   100.62
# 118  100.227  100.318  100.379
# 119  100.098  100.197  100.193
# 120  100.417  100.417  100.417

# %%
price_30=erk.bond_price(30,100,.05,12,rates)
price_30[[1,2,3]].tail()
# Out:
#            1        2        3
# 116  129.029  124.012  143.975
# 117  124.746  127.793  139.502
# 118  119.566  128.762  135.421
# 119  116.472  136.819  135.991
# 120  122.809  133.297  131.959

# %%
## long bonds are not good for hedge

# %%
rets_30=erk.bond_total_return(price_30,100,0.05,12)
rets_10=erk.bond_total_return(price_10,100,0.05,12)
rets_bonds = 0.6*rets_10+0.4*rets_30

# %%
mean_rets_bonds = rets_bonds.mean(axis='columns')
erk.summary_stats(pd.DataFrame(mean_rets_bonds))
# Out:
#    Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# 0            0.03527        0.003735  0.510705  4.010298
#
#    Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# 0                 -0.00131           -0.000762      1.373333           0.0

# %%
price_eq = erk.gbm(n_years = 10 , n_scenarios=500,mu=0.07,sigma=0.15)
price_eq.shape
# Out:
# (121, 500)

# %%
rets_eq = price_eq.pct_change().dropna()
rets_eq.shape
# Out:
# (120, 500)

# %%
rets_bonds.shape
# Out:
# (120, 500)

# %%
rets = 0.7*rets_eq+.3*rets_bonds
rets_mean = rets.mean(axis='columns')
erk.summary_stats(pd.DataFrame(rets_mean))
# Out:
#    Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# 0           0.057003        0.004828 -0.234867  2.874815
#
#    Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# 0                -0.002254           -0.001674      5.443886           0.0
