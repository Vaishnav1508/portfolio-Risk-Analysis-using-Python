# %% [markdown]
# ### RANDOM WALK GENERATION

# %%
##goemetric bound motion
import pandas as pd
import numpy as np
def gbm(n_years=10,n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    '''
    Evolution of a stock price using a geometric brownian motion model
    '''
    dt = 1/steps_per_year
    n_steps =int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps,n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    # to prices
    prices = s_0*(1+rets).cumprod()
    return prices

# %%
p = gbm(10, n_scenarios=3)

# %%
p.head()
# Out:
#             0           1           2
# 0   99.209617   98.385768   98.197892
# 1   94.933367   96.595301  107.188999
# 2   96.522627  100.169773  103.466461
# 3   98.065857   98.890770  112.188630
# 4  102.041955  101.443665  100.396695

# %%
p.plot()

# %%
p = gbm(n_years=10,n_scenarios=1000).plot(figsize=(12,6),legend=False)

# %%
'''def gbm0(n_years=10,n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    
    dt = 1/steps_per_year
    n_steps =int(n_years*steps_per_year)
    xi = np.random.normal(size=(n_steps,n_scenarios))
    rets = mu*dt + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    # to prices
    prices = s_0*(1+rets).cumprod()
    return prices '''

def gbm(n_years=10,n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
  
    dt = 1/steps_per_year
    n_steps =int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+mu*dt),scale=(sigma*np.sqrt(dt)),size=(n_steps,n_scenarios))
    prices = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
## gbm1 takes lesser time as it avoids loops by using panda effieciently

# %%
gbm(n_years=10,n_scenarios=20).plot(legend=False,figsize=(12,6))

# %%
def gbm(n_years=10,n_scenarios=1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
  
    dt = 1/steps_per_year
    n_steps =int(n_years*steps_per_year)
    rets_plus_1 = np.random.normal(loc=(1+mu*dt),scale=(sigma*np.sqrt(dt)),size=(n_steps,n_scenarios))
    rets_plus_1[0] = 1
    prices = s_0*pd.DataFrame(rets_plus_1).cumprod()
    return prices

# %%
gbm(n_years=10,n_scenarios=20).head()
# Out:
#             0           1           2           3           4           5  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1  101.338893  104.887639   98.855539  104.833341  106.136471   99.114089
# 2  101.973099  103.901666  103.942977  102.398664  107.036831  100.633173
# 3  108.712582  109.770411  104.343405  107.297728  104.690707   98.006056
# 4  101.982999  108.770703  100.136341  110.092472  105.115407  104.943579
#
#             6           7           8           9          10          11  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   97.196793   98.265380   99.005316  110.618347   99.275105  103.285921
# 2   98.663574   96.679035   97.062829  115.325838   93.868413   99.470920
# 3  102.064773   90.740860   97.427956  118.345329   95.696801  103.164165
# 4  111.680955   88.167891   93.392223  118.010729   96.506518  104.550975
#
#            12          13          14          15          16          17  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1  108.063600  101.235294   91.801631   98.106079   99.870704   98.576407
# 2  111.503085  107.781641   93.207735   89.364826   96.552109   95.737000
# 3  111.237305  110.515949   91.738732   90.362086  107.216848   89.072502
# 4  114.108498  108.582074   89.206410   94.950719  107.703540   89.615651
#
#            18          19
# 0  100.000000  100.000000
# 1  105.250911  100.790499
# 2  103.039702  108.315043
# 3  107.609009  111.933177
# 4  102.829738  111.182254
