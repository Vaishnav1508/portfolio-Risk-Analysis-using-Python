# %%
# %load_ext autoreload
# %autoreload 2
import edhec_risk_kit as erk
import pandas as pd
import numpy as np
from scipy.optimize import minimize
ind = erk.get_ind_returns()
er = erk.annualize_rets(ind["1996":"2000"],12)
cov= ind["1996":"2000"].cov()

# %%
l=["Books","Steel","Oil","Mines"]
er[l]
# Out:
# Books    0.187286
# Steel    0.115809
# Oil      0.165377
# Mines   -0.053554
# dtype: float64

# %%
erk.msr(0.1, er[l],cov.loc[l,l]),
# Out:
# (array([0.75040364, 0.24959636]),)

# %%
erk.plot_ef(20,er,cov,show_cml=True,risk_free_rate=0.1,style='.-')

# %%
erk.msr(0.1,np.array([0.11,0.12]),cov.loc[l,l]),erk.msr(0.1, er[l],cov.loc[l,l])
# Out:
# (array([0.57930354, 0.42069646]), array([0.75040364, 0.24959636]))

# %%
erk.plot_ef(20 ,er,cov,show_cml=True,style='.-',risk_free_rate=0.1,show_ew=True)

# %%
erk.plot_ef(20 ,er,cov,show_cml=True,style='.-',risk_free_rate=0.1,show_ew=True,show_gmv=True)

# %%
erk.msr(0.1,er,cov)
# Out:
# array([6.28071491e-15, 4.19997296e-15, 9.59458018e-15, 0.00000000e+00,
#        7.73818036e-15, 7.83506948e-18, 0.00000000e+00, 4.55961483e-01,
#        7.30871147e-16, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 2.33810836e-01, 0.00000000e+00, 1.07128050e-14,
#        0.00000000e+00, 1.38704167e-01, 1.23239026e-14, 8.94091667e-02,
#        5.66076244e-17, 0.00000000e+00, 1.55177025e-02, 4.45981797e-16,
#        0.00000000e+00, 3.08358242e-15, 6.65966443e-02, 0.00000000e+00,
#        6.19166773e-15, 0.00000000e+00])
